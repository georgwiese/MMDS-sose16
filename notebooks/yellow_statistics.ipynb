# %% [markdown]
# # Basic Analysis
# This Notebook will compute (and plot) some basic statistics on a sample of the data.

# %%
# Initialization

import pandas as pd

# %matplotlib inline
pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.line_width', 5000) 
pd.set_option('display.max_columns', 60)

DATA_PATH = "../data/yellow_sample.csv"

# %% [markdown]
# ## Sample

# %%
data = pd.read_csv("../data/yellow_sample_001.csv")
data
# Out:
#    Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  Trip_Distance  Start_Lon  Start_Lat    End_Lon    End_Lat
# 0   2009-01-06 19:21:59   2009-01-06 19:39:10                1          5.900 -74.005048  40.741052 -73.989259  40.665735
# 1   2009-01-13 13:13:00   2009-01-13 13:26:00                1          1.250 -73.979138  40.749900 -73.990875  40.734405
# 2   2009-01-15 19:39:47   2009-01-15 19:45:23                1          1.000 -73.982754  40.773216 -73.984115  40.759927
# 3   2009-01-24 23:57:35   2009-01-25 00:02:41                1          0.500 -73.995319  40.717407 -73.988406  40.721479
# 4   2009-01-09 22:19:00   2009-01-09 22:21:00                2          0.300 -74.004818  40.750280 -74.000155  40.747998
# 5   2009-01-01 21:26:00   2009-01-01 21:56:00                2          8.520 -73.983155  40.763358 -73.873183  40.738977
# 6   2009-01-27 23:27:00   2009-01-27 23:41:00                5          3.020 -73.997505  40.719487 -74.015402  40.704758
# ...

# %%
data.Passenger_Count.value_counts().plot(kind="bar")
